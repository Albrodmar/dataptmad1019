# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
titanic.select_dtypes(include=[np.number])
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
#your code here- categorical variable
titanic.select_dtypes(exclude=[np.number])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# 3                 113803  C123        S
# 4                 373450    U0        S
# ...                  ...   ...      ...
# 1304           A.5. 3236    U0        S
# 1305            PC 17758  C105        C
# 1306  SOTON/O.Q. 3101262    U0        S
# 1307              359309    U0        S
# 1308                2668    U0        C
#
# [1309 rows x 5 columns]

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
import matplotlib.style as mapstyle

mapstyle.use('classic')
fig = plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
age = titanic['Age']

fig, ax = plt.subplots()
ax.hist(age)
ax.set_title('Age')
plt.show()

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
bins_list = [0,10, 20, 50]
ax = plt.hist(age, bins = bins_list)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %% [markdown]
# #your comment here
# It makes more difficult to compare, because the have different ranges.

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
import seaborn as sns
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
fig, ax = plt.subplots()

ax.bar(['male', 'female'],list(titanic['Gender'].value_counts()))
# Out:
# <BarContainer object of 2 artists>

# %%
# your code here- 2nd way
sns.countplot(titanic['Gender'])

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot(titanic['Pclass'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
plt.boxplot(titanic['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fb51f740a90>,
#   <matplotlib.lines.Line2D at 0x7fb51f733e10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fb51f747590>,
#   <matplotlib.lines.Line2D at 0x7fb51f747a90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fb51f733dd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fb51f747fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fb51f74f510>],
#  'means': []}

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here
More than 75% of the passenger were younger than 40

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
plt.hist(titanic['Age'],bins = 80)
# Out:
# (array([22., 12.,  7., 10.,  5.,  6.,  4.,  6., 13.,  4.,  4.,  4.,  9.,
#         16.,  9., 19., 20., 43., 32., 28., 42., 51., 45., 65., 41., 33.,
#         36., 68., 36., 72., 34., 27., 71., 16., 30., 33., 12., 14., 26.,
#         18., 20., 25., 10., 13., 23., 10., 19., 16., 15., 16., 10.,  6.,
#          5., 10.,  8.,  5.,  5.,  6.,  3.,  7.,  6.,  6.,  4.,  5.,  3.,
#          1.,  1.,  0.,  0.,  2.,  3.,  0.,  0.,  1.,  0.,  1.,  0.,  0.,
#          0.,  1.]),
#  array([ 0.17    ,  1.167875,  2.16575 ,  3.163625,  4.1615  ,  5.159375,
#          6.15725 ,  7.155125,  8.153   ,  9.150875, 10.14875 , 11.146625,
#         12.1445  , 13.142375, 14.14025 , 15.138125, 16.136   , 17.133875,
#         18.13175 , 19.129625, 20.1275  , 21.125375, 22.12325 , 23.121125,
#         24.119   , 25.116875, 26.11475 , 27.112625, 28.1105  , 29.108375,
#         30.10625 , 31.104125, 32.102   , 33.099875, 34.09775 , 35.095625,
#         36.0935  , 37.091375, 38.08925 , 39.087125, 40.085   , 41.082875,
#         42.08075 , 43.078625, 44.0765  , 45.074375, 46.07225 , 47.070125,
#         48.068   , 49.065875, 50.06375 , 51.061625, 52.0595  , 53.057375,
#         54.05525 , 55.053125, 56.051   , 57.048875, 58.04675 , 59.044625,
#         60.0425  , 61.040375, 62.03825 , 63.036125, 64.034   , 65.031875,
#         66.02975 , 67.027625, 68.0255  , 69.023375, 70.02125 , 71.019125,
#         72.017   , 73.014875, 74.01275 , 75.010625, 76.0085  , 77.006375,
#         78.00425 , 79.002125, 80.      ]),
#  <a list of 80 Patch objects>)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
Passengers with 29 and 32 years old were the most common.

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
titanic[['Fare','Age']].corr()
# Out:
#           Fare       Age
# Fare  1.000000  0.171355
# Age   0.171355  1.000000

# %%
# your code-2nd way
#sns.heatmap(titanic[['Fare','Age']].corr())
sns.relplot(x='Fare', y='Age', data= titanic)

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic[['Fare','Age','Survived','Gender']].corr())

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
##'Fare' and 'Survived' are the most correlated features.

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
titanic.boxplot(column=['Age'], 
                 by=['Pclass'],
                 fontsize=15,
                 figsize=(8, 8));

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
titanic.boxplot(column=['Age'], 
                 by=['Gender'],
                 fontsize=15,
                 figsize=(8, 8));
