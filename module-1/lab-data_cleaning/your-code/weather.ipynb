# %% [markdown]
# ## Global Historical Climatology Network Dataset
# Variables are stored in both rows and columns
# This dataset represents the daily weather records for a weather station (MX17004) in Mexico for five months in 2010.

# %%
import pandas as pd
import os

# %%
os.path.abspath('main.ipynb') #checking the path....
# Out:
# '/home/alberto/Ironhack/dataptmad1019/module-1/lab-data_cleaning/your-code/main.ipynb'

# %%
df=pd.read_csv('/home/alberto/Ironhack/dataptmad1019/module-1/lab-data_cleaning/weather-raw.csv')
df
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
nullcolumns=df.isnull().sum()
#nullcolumns/len(df)*100
display(nullcolumns[nullcolumns==22])
# Out:
# d9     22
# d12    22
# d18    22
# d19    22
# d20    22
# d21    22
# d22    22
# d24    22
# dtype: int64

# %%
nullcolumns[nullcolumns==22]/len(df)*100
# Out:
# d9     100.0
# d12    100.0
# d18    100.0
# d19    100.0
# d20    100.0
# d21    100.0
# d22    100.0
# d24    100.0
# dtype: float64

# %%
import missingno

# %%
missingno.bar(df);

# %%
threshold = 0

nullfilter = nullcolumns[nullcolumns == 22]

#drop_columns = list(nullcolumns[nullfilter].index)

#drop_columns
# Out:
# d9     22
# d12    22
# d18    22
# d19    22
# d20    22
# d21    22
# d22    22
# d24    22
# dtype: int64

# %%
len(df)
# Out:
# 22

# %%
#df_1=df[x for x in df.columns if x not in drop_columns]
#df_2=df.drop(drop_columns, axis=1)
df_3=df.drop(nullfilter, axis=1, inplace=True)

# %%
len(df.columns)
# Out:
# 34

# %%
display(df) #non sense I do not have any temperature
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...
